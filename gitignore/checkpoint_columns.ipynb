# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('./source_data/COVID-19_Vaccinations_in_the_United_States_County.csv')

# %%
df.shape
# Out:
# (1486676, 53)

# %%
df.head()
# Out:
#          Date   FIPS  MMWR_week        Recip_County Recip_State  \
# 0  03/10/2022  19041         10         Clay County          IA
# 1  03/10/2022    UNK         10      Unknown County          KY
# 2  03/10/2022  28101         10       Newton County          MS
# 3  03/10/2022    UNK         10      Unknown County          GA
# 4  03/10/2022  29133         10  Mississippi County          MO
#
#    Completeness_pct  Administered_Dose1_Recip  Administered_Dose1_Pop_Pct  \
# 0              97.4                    8985.0                        56.1
# 1              94.0                  195520.0                         0.0
# 2              98.1                   12815.0                        61.0
# 3              89.7                  942846.0                         0.0
# 4              91.3                    6385.0                        48.4
#
#    Administered_Dose1_Recip_5Plus  Administered_Dose1_Recip_5PlusPop_Pct  \
# 0                          8985.0                                   59.9
# 1                        195475.0                                    0.0
# 2                         12811.0                                   65.3
# 3                        941952.0                                    0.0
# 4                          6385.0                                   51.1
#
#    Administered_Dose1_Recip_12Plus  Administered_Dose1_Recip_12PlusPop_Pct  \
# 0                           8781.0                                    64.5
# 1                         192474.0                                     0.0
# 2                          12529.0                                    71.2
# 3                         898355.0                                     0.0
# 4                           6327.0                                    55.4
#
#    Administered_Dose1_Recip_18Plus  Administered_Dose1_Recip_18PlusPop_Pct  \
# 0                           8322.0                                    67.2
# 1                         184407.0                                     0.0
# 2                          11843.0                                    75.4
# 3                         839911.0                                     0.0
# 4                           6101.0                                    58.5
#
#    Administered_Dose1_Recip_65Plus  Administered_Dose1_Recip_65PlusPop_Pct  \
# 0                           3149.0                                    93.0
# 1                          51898.0                                     0.0
# 2                           3763.0                                    95.0
# 3                         128901.0                                     0.0
# 4                           1981.0                                    82.8
#
#    Series_Complete_Yes  Series_Complete_Pop_Pct  Series_Complete_5Plus  \
# 0                 8256                     51.5                 8256.0
# 1               152031                      0.0               152021.0
# 2                11098                     52.8                11098.0
# 3               591326                      0.0               591191.0
# 4                 5636                     42.8                 5636.0
#
#    Series_Complete_5PlusPop_Pct  Series_Complete_12Plus  \
# 0                          55.0                  8088.0
# 1                           0.0                149745.0
# 2                          56.6                 10927.0
# 3                           0.0                563339.0
# 4                          45.1                  5604.0
#
#    Series_Complete_12PlusPop_Pct  Series_Complete_18Plus  \
# 0                           59.4                    7680
# 1                            0.0                  143320
# 2                           62.1                   10348
# 3                            0.0                  524225
# 4                           49.1                    5425
#
#    Series_Complete_18PlusPop_Pct  Series_Complete_65Plus  \
# 0                           62.1                    2948
# 1                            0.0                   38454
# 2                           65.9                    3484
# 3                            0.0                   71397
# 4                           52.0                    1781
#
#    Series_Complete_65PlusPop_Pct  Booster_Doses  Booster_Doses_Vax_Pct  \
# 0                           87.1         4356.0                   52.8
# 1                            0.0        56751.0                   37.3
# 2                           95.0         3832.0                   34.5
# 3                            0.0       134445.0                   22.7
# 4                           74.4         2064.0                   36.6
#
#    Booster_Doses_12Plus  Booster_Doses_12Plus_Vax_Pct  Booster_Doses_18Plus  \
# 0                4356.0                          53.9                4302.0
# 1               56748.0                          37.9               55827.0
# 2                3832.0                          35.1                3754.0
# 3              134345.0                          23.8              129064.0
# 4                2064.0                          36.8                2052.0
#
#    Booster_Doses_18Plus_Vax_Pct  Booster_Doses_50Plus  \
# 0                          56.0                3448.0
# 1                          39.0               41922.0
# 2                          36.3                3057.0
# 3                          24.6               72983.0
# 4                          37.8                1549.0
#
#    Booster_Doses_50Plus_Vax_Pct  Booster_Doses_65Plus  \
# 0                          68.9                2320.0
# 1                          51.5               25568.0
# 2                          47.2                1956.0
# 3                          34.7               31647.0
# 4                          45.4                 878.0
#
#    Booster_Doses_65Plus_Vax_Pct SVI_CTGY  Series_Complete_Pop_Pct_SVI  \
# 0                          78.7        B                          8.0
# 1                          66.5      NaN                          NaN
# 2                          56.1        D                         16.0
# 3                          44.3      NaN                          NaN
# 4                          49.3        D                         15.0
#
#    Series_Complete_5PlusPop_Pct_SVI  Series_Complete_12PlusPop_Pct_SVI  \
# 0                               8.0                                8.0
# 1                               NaN                                NaN
# 2                              16.0                               16.0
# 3                               NaN                                NaN
# 4                              15.0                               15.0
#
#    Series_Complete_18PlusPop_Pct_SVI  Series_Complete_65PlusPop_Pct_SVI  \
# 0                                8.0                                8.0
# 1                                NaN                                NaN
# 2                               16.0                               16.0
# 3                                NaN                                NaN
# 4                               16.0                               16.0
#
#   Metro_status  Series_Complete_Pop_Pct_UR_Equity  \
# 0    Non-metro                                8.0
# 1          NaN                                NaN
# 2    Non-metro                                8.0
# 3          NaN                                NaN
# 4    Non-metro                                7.0
#
#    Series_Complete_5PlusPop_Pct_UR_Equity  \
# 0                                     8.0
# 1                                     NaN
# 2                                     8.0
# 3                                     NaN
# 4                                     7.0
#
#    Series_Complete_12PlusPop_Pct_UR_Equity  \
# 0                                      8.0
# 1                                      NaN
# 2                                      8.0
# 3                                      NaN
# 4                                      7.0
#
#    Series_Complete_18PlusPop_Pct_UR_Equity  \
# 0                                      8.0
# 1                                      NaN
# 2                                      8.0
# 3                                      NaN
# 4                                      8.0
#
#    Series_Complete_65PlusPop_Pct_UR_Equity  Census2019  Census2019_5PlusPop  \
# 0                                      8.0     16016.0              15005.0
# 1                                      NaN         NaN                  NaN
# 2                                      8.0     21018.0              19614.0
# 3                                      NaN         NaN                  NaN
# 4                                      8.0     13180.0              12485.0
#
#    Census2019_12PlusPop  Census2019_18PlusPop  Census2019_65PlusPop
# 0               13610.0               12375.0                3386.0
# 1                   NaN                   NaN                   NaN
# 2               17586.0               15708.0                3585.0
# 3                   NaN                   NaN                   NaN
# 4               11412.0               10436.0                2393.0

# %%
df['Date']  = pd.to_datetime(df['Date'])

# %%
df.dtypes

# %%
df['Recip_County'] = df['Recip_County'] + '_' + df['Recip_State']

# %%
drop_states = ['AS','FM','GU','MH','MP','PR','PW','VI','UNK'] # drop anything that's not 50 contiguous + DC
df = df[df['Recip_State'].map(lambda x : x not in drop_states)]

# %%
df.groupby('Metro_status').mean().T
# Out:
# Metro_status                                     Metro     Non-metro
# MMWR_week                                    24.388521     24.388521
# Completeness_pct                             79.315544     77.248979
# Administered_Dose1_Recip                 107986.335913   8199.864311
# Administered_Dose1_Pop_Pct                   36.854922     31.303182
# Administered_Dose1_Recip_5Plus           174974.654839  12651.318842
# Administered_Dose1_Recip_5PlusPop_Pct        63.661780     53.126906
# Administered_Dose1_Recip_12Plus          108296.507650   8252.353173
# Administered_Dose1_Recip_12PlusPop_Pct       41.766313     35.159114
# Administered_Dose1_Recip_18Plus          101350.948589   7870.875607
# Administered_Dose1_Recip_18PlusPop_Pct       43.472565     37.105310
# Administered_Dose1_Recip_65Plus           27409.383994   2914.019648
# Administered_Dose1_Recip_65PlusPop_Pct       60.006095     53.224683
# Series_Complete_Yes                       88684.285898   6828.045001
# Series_Complete_Pop_Pct                      31.424524     27.848376
# Series_Complete_5Plus                    149411.135903  11193.460667
# Series_Complete_5PlusPop_Pct                 56.084977     48.733620
# Series_Complete_12Plus                    88337.058591   6821.585042
# Series_Complete_12PlusPop_Pct                36.428117     32.295096
# Series_Complete_18Plus                    82816.732816   6525.500521
# Series_Complete_18PlusPop_Pct                38.002807     34.151937
# Series_Complete_65Plus                    22547.069508   2456.203667
# Series_Complete_65PlusPop_Pct                53.968373     50.082218
# Booster_Doses                             58699.360289   4429.374729
# Booster_Doses_Vax_Pct                        37.545845     39.326657
# Booster_Doses_12Plus                      65907.706360   4857.784255
# Booster_Doses_12Plus_Vax_Pct                 41.313461     42.545398
# Booster_Doses_18Plus                      57310.493498   4374.652679
# Booster_Doses_18Plus_Vax_Pct                 40.227064     41.492516
# Booster_Doses_50Plus                      36762.128318   3402.999351
# Booster_Doses_50Plus_Vax_Pct                 51.024352     51.661717
# Booster_Doses_65Plus                      20476.152906   2165.480617
# Booster_Doses_65Plus_Vax_Pct                 59.649060     60.062692
# Series_Complete_Pop_Pct_SVI                   7.663016      8.354737
# Series_Complete_5PlusPop_Pct_SVI              8.931105      9.578367
# Series_Complete_12PlusPop_Pct_SVI             7.964617      8.735757
# Series_Complete_18PlusPop_Pct_SVI             8.049935      8.872282
# Series_Complete_65PlusPop_Pct_SVI             8.344416      9.224781
# Series_Complete_Pop_Pct_UR_Equity             2.395414      6.127968
# Series_Complete_5PlusPop_Pct_UR_Equity        3.550884      7.206315
# Series_Complete_12PlusPop_Pct_UR_Equity       2.688807      6.500513
# Series_Complete_18PlusPop_Pct_UR_Equity       2.782310      6.645308
# Series_Complete_65PlusPop_Pct_UR_Equity       3.080485      6.997454
# Census2019                               242003.826758  23318.409620
# Census2019_5PlusPop                      226983.418700  22275.708330
# Census2019_12PlusPop                     206421.130360  20017.171241
# Census2019_18PlusPop                     187953.263293  18248.007089
# Census2019_65PlusPop                      38490.512864   4646.580759

# %%
cluster_df = df.groupby('Recip_County').mean().sort_values(by = 'Completeness_pct')

# %%
cluster_df.dropna(inplace = True) #won't be able to fit DBSCAN with nulls.

# %%
ss = StandardScaler()
X_scaled = ss.fit_transform(cluster_df)
dbscan = DBSCAN()
dbscan.fit(X_scaled)

# %%
dbscan.labels_

# %%
km = KMeans(n_clusters=3, random_state=42)
km.fit(X_scaled)

# %%
cluster_df['cluster'] = km.labels_

# %%
cluster_df.groupby('cluster').mean()

# %% [markdown]
# ### Filter to only Administered Dose Recipients, Administered Dose Pct, Series Complete Pop PCT, Booster Doses Vax Pct.  Df should have columns with data from 3 specific checkpoint dates: 030121, 090121, 030122

# %%
df_030121 = df.loc[(df['Date'] == '03/01/2021')] # filter to only data from this date
df_030121 = df_030121[['Recip_County','Administered_Dose1_Recip', 'Administered_Dose1_Pop_Pct', 'Series_Complete_Pop_Pct_SVI', 'Booster_Doses_Vax_Pct']] #filter to wanted columns
df_030121 = df_030121.rename(columns={'Administered_Dose1_Recip': 'Administered_Dose1_Recip_030121',      #label each column with the date
                                      'Administered_Dose1_Pop_Pct':'Administered_Dose1_Pop_Pct_030121', 
                                      'Series_Complete_Pop_Pct_SVI':'Series_Complete_Pop_Pct_SVI_030121',
                                      'Booster_Doses_Vax_Pct': 'Booster_Doses_Vax_Pct_030121'}) 

df_090121 = df.loc[(df['Date'] == '09/01/2021')]
df_090121 = df_090121[['Recip_County','Administered_Dose1_Recip', 'Administered_Dose1_Pop_Pct', 'Series_Complete_Pop_Pct_SVI', 'Booster_Doses_Vax_Pct']]
df_090121 = df_090121.rename(columns={'Administered_Dose1_Recip': 'Administered_Dose1_Recip_090121', 
                                      'Administered_Dose1_Pop_Pct':'Administered_Dose1_Pop_Pct_090121', 
                                      'Series_Complete_Pop_Pct_SVI':'Series_Complete_Pop_Pct_SVI_090121',
                                      'Booster_Doses_Vax_Pct': 'Booster_Doses_Vax_Pct_090121'})

df_030122 = df.loc[(df['Date'] == '03/01/2022')]
df_030122 = df_030122[['Recip_County','Administered_Dose1_Recip', 'Administered_Dose1_Pop_Pct', 'Series_Complete_Pop_Pct_SVI', 'Booster_Doses_Vax_Pct']]
df_030122 = df_030122.rename(columns={'Administered_Dose1_Recip': 'Administered_Dose1_Recip_030122',
                                      'Administered_Dose1_Pop_Pct':'Administered_Dose1_Pop_Pct_030122', 
                                      'Series_Complete_Pop_Pct_SVI':'Series_Complete_Pop_Pct_SVI_030122',
                                      'Booster_Doses_Vax_Pct': 'Booster_Doses_Vax_Pct_030122'})

data_3dates_df = pd.merge(df_030121,df_090121).merge(df_030122) # merge all three dfs
data_3dates_df.set_index('Recip_County', inplace = True) # set index to county name
data_3dates_df.head()

# %%
df_030121.shape,df_090121.shape, df_030122.shape, data_3dates_df.shape

# %%
data_3dates_df.fillna('0', inplace = True) # In this data, NaNs are stand-ins for "0", so imputing with "0".

# %%
data_3dates_df.isnull().sum()

# %%
data_3dates_df.to_csv('./clean_data/checkpoint_cols.csv')
